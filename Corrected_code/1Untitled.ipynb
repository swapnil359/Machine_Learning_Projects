# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel(r'C:\Users\Laptops\Datamites\ModelMates_2024\default of credit card clients.xls', engine='xlrd')
# Drop first column
df.columns = df.iloc[0]
df = df.drop(0).reset_index(drop=True)
df.drop(columns = ['ID'], inplace = True)
df['LIMIT_BAL'] = pd.to_numeric(df['LIMIT_BAL'], errors='coerce')
df['LIMIT_BAL_sqrt'] = np.sqrt(df['LIMIT_BAL'])
Q1 = df['LIMIT_BAL_sqrt'].quantile(0.25)
Q3 = df['LIMIT_BAL_sqrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['LIMIT_BAL_sqrt'] = df['LIMIT_BAL_sqrt'].clip(lower=lower_bound, upper=upper_bound)
# For column Bill_Amt1
df['BILL_AMT1'] = pd.to_numeric(df['BILL_AMT1'], errors='coerce')
df['BILL_AMT1_cbrt'] = np.cbrt(df['BILL_AMT1'])
Q1 = df['BILL_AMT1_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT1_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT1_cbrt'] = df['BILL_AMT1_cbrt'].clip(lower=lower_bound, upper=upper_bound)
df['BILL_AMT1_cbrt_binned'] = pd.qcut(df['BILL_AMT1_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['BILL_AMT1_cbrt_binned'] = df['BILL_AMT1_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
# For column Bill_Amt2
df['BILL_AMT2'] = pd.to_numeric(df['BILL_AMT2'], errors='coerce')
df['BILL_AMT2_cbrt'] = np.cbrt(df['BILL_AMT2'])
Q1 = df['BILL_AMT2_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT2_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT2_cbrt'] = df['BILL_AMT2_cbrt'].clip(lower=lower_bound, upper=upper_bound)
df['BILL_AMT2_cbrt_binned'] = pd.qcut(df['BILL_AMT2_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['BILL_AMT2_cbrt_binned'] = df['BILL_AMT2_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})

# For column Bill_Amt3
df['BILL_AMT3'] = pd.to_numeric(df['BILL_AMT3'], errors='coerce')
df['BILL_AMT3_cbrt'] = np.cbrt(df['BILL_AMT3'])
Q1 = df['BILL_AMT3_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT3_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT3_cbrt'] = df['BILL_AMT3_cbrt'].clip(lower=lower_bound, upper=upper_bound)
df['BILL_AMT3_cbrt_binned'] = pd.qcut(df['BILL_AMT3_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['BILL_AMT3_cbrt_binned'] = df['BILL_AMT3_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
# For column Bill_Amt4
df['BILL_AMT4'] = pd.to_numeric(df['BILL_AMT4'], errors='coerce')
df['BILL_AMT4_cbrt'] = np.cbrt(df['BILL_AMT4'])
Q1 = df['BILL_AMT4_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT4_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT4_cbrt'] = df['BILL_AMT4_cbrt'].clip(lower=lower_bound, upper=upper_bound)
df['BILL_AMT4_cbrt_binned'] = pd.qcut(df['BILL_AMT4_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['BILL_AMT4_cbrt_binned'] = df['BILL_AMT4_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
# For column Bill_Amt5
df['BILL_AMT5'] = pd.to_numeric(df['BILL_AMT5'], errors='coerce')
df['BILL_AMT5_cbrt'] = np.cbrt(df['BILL_AMT5'])
Q1 = df['BILL_AMT5_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT5_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT5_cbrt'] = df['BILL_AMT5_cbrt'].clip(lower=lower_bound, upper=upper_bound)
df['BILL_AMT5_cbrt_binned'] = pd.qcut(df['BILL_AMT5_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['BILL_AMT5_cbrt_binned'] = df['BILL_AMT5_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
# For column Bill_Amt6
df['BILL_AMT6'] = pd.to_numeric(df['BILL_AMT6'], errors='coerce')
df['BILL_AMT6_cbrt'] = np.cbrt(df['BILL_AMT6'])
Q1 = df['BILL_AMT6_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT6_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT6_cbrt'] = df['BILL_AMT6_cbrt'].clip(lower=lower_bound, upper=upper_bound)
df['BILL_AMT6_cbrt_binned'] = pd.qcut(df['BILL_AMT6_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['BILL_AMT6_cbrt_binned'] = df['BILL_AMT6_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
# For column pay_Amt1
df['PAY_AMT1']=pd.to_numeric(df['PAY_AMT1'],errors='coerce')
df['PAY_AMT1_cbrt'] = np.cbrt(df['PAY_AMT1'])
Q1 = df['PAY_AMT1_cbrt'].quantile(0.25)
Q3 = df['PAY_AMT1_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['PAY_AMT1_cbrt'] = df['PAY_AMT1_cbrt'].clip(lower=lower_bound, upper=upper_bound)
df['PAY_AMT1_cbrt_binned'] = pd.qcut(df['PAY_AMT1_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['PAY_AMT1_cbrt_binned'] = df['PAY_AMT1_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
# For column pay_Amt2
df['PAY_AMT2']=pd.to_numeric(df['PAY_AMT2'],errors='coerce')
df['PAY_AMT2_cbrt']=np.cbrt(df['PAY_AMT2'])
Q1 = df['PAY_AMT2_cbrt'].quantile(0.25)
Q3 = df['PAY_AMT2_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['PAY_AMT2_cbrt'] = df['PAY_AMT2_cbrt'].clip(lower=lower_bound, upper=upper_bound)
df['PAY_AMT2_cbrt_binned'] = pd.qcut(df['PAY_AMT2_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['PAY_AMT2_cbrt_binned'] = df['PAY_AMT2_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
# For column pay_Amt3
df['PAY_AMT3']=pd.to_numeric(df['PAY_AMT3'],errors='coerce')
df['PAY_AMT3_cbrt']=np.cbrt(df['PAY_AMT3'])
Q1 = df['PAY_AMT3_cbrt'].quantile(0.25)
Q3 = df['PAY_AMT3_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['PAY_AMT3_cbrt'] = df['PAY_AMT3_cbrt'].clip(lower=lower_bound, upper=upper_bound)
df['PAY_AMT3_cbrt_binned'] = pd.qcut(df['PAY_AMT3_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['PAY_AMT3_cbrt_binned'] = df['PAY_AMT3_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
# For column pay_Amt4
df['PAY_AMT4']=pd.to_numeric(df['PAY_AMT4'],errors='coerce')
df['PAY_AMT4_cbrt']=np.cbrt(df['PAY_AMT4'])
Q1 = df['PAY_AMT4_cbrt'].quantile(0.25)
Q3 = df['PAY_AMT4_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['PAY_AMT4_cbrt'] = df['PAY_AMT4_cbrt'].clip(lower=lower_bound, upper=upper_bound)
df['PAY_AMT4_cbrt_binned'] = pd.qcut(df['PAY_AMT4_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['PAY_AMT4_cbrt_binned'] = df['PAY_AMT4_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
# For column pay_Amt5
df['PAY_AMT5']=pd.to_numeric(df['PAY_AMT5'],errors='coerce')
df['PAY_AMT5_cbrt']=np.cbrt(df['PAY_AMT5'])
Q1 = df['PAY_AMT5_cbrt'].quantile(0.25)
Q3 = df['PAY_AMT5_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['PAY_AMT5_cbrt'] = df['PAY_AMT5_cbrt'].clip(lower=lower_bound, upper=upper_bound)
df['PAY_AMT5_cbrt_binned'] = pd.qcut(df['PAY_AMT5_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['PAY_AMT5_cbrt_binned'] = df['PAY_AMT5_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
# for column pay_Amt6
df['PAY_AMT6']=pd.to_numeric(df['PAY_AMT6'],errors='coerce')
df['PAY_AMT6_cbrt']=np.cbrt(df['PAY_AMT6'])
Q1 = df['PAY_AMT6_cbrt'].quantile(0.25)
Q3 = df['PAY_AMT6_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['PAY_AMT6_cbrt'] = df['PAY_AMT6_cbrt'].clip(lower=lower_bound, upper=upper_bound)
df['PAY_AMT6_cbrt_binned'] = pd.qcut(df['PAY_AMT6_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['PAY_AMT6_cbrt_binned'] = df['PAY_AMT6_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
#for column age
df['AGE']=pd.to_numeric(df['AGE'],errors='coerce')
df['AGE_sqrt']=np.sqrt(df['AGE'])
Q1 = df['AGE_sqrt'].quantile(0.25)
Q3 = df['AGE_sqrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['AGE_sqrt'] = df['AGE_sqrt'].clip(lower=lower_bound, upper=upper_bound)

# %%
df['AGE'].unique()
# Out:
# array([24, 26, 34, 37, 57, 29, 23, 28, 35, 51, 41, 30, 49, 39, 40, 27, 47,
#        33, 32, 54, 58, 22, 25, 31, 46, 42, 43, 45, 56, 44, 53, 38, 63, 36,
#        52, 48, 55, 60, 50, 75, 61, 73, 59, 21, 67, 66, 62, 70, 72, 64, 65,
#        71, 69, 68, 79, 74], dtype=object)

# %%
df['AGE'].nunique()
# Out:
# 56

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['AGE'], bins=30, kde=True)
plt.title('Distribution of AGE')
plt.show()

# %%
df['AGE'].skew()
# Out:
# 0.7322458687830562

# %%
df['EDUCATION'] = df['EDUCATION'].replace([4, 5, 6, 0], 3)

# %%
df['EDUCATION'].value_counts()
# Out:
# EDUCATION
# 2    14030
# 1    10585
# 3     5385
# Name: count, dtype: int64

# %%
df['MARRIAGE'].value_counts()
# Out:
# MARRIAGE
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: count, dtype: int64

# %%
df['MARRIAGE'] = df['MARRIAGE'].replace([0], 3)

# %%
df['MARRIAGE'].value_counts()
# Out:
# MARRIAGE
# 2    15964
# 1    13659
# 3      377
# Name: count, dtype: int64

# %%
sns.boxplot(x='default payment next month', y='LIMIT_BAL', data=df)
# Out:
# <Axes: xlabel='default payment next month', ylabel='LIMIT_BAL'>

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'LIMIT_BAL_sqrt', 'BILL_AMT1_cbrt',
#        'BILL_AMT1_cbrt_binned', 'BILL_AMT2_cbrt', 'BILL_AMT2_cbrt_binned',
#        'BILL_AMT3_cbrt', 'BILL_AMT3_cbrt_binned', 'BILL_AMT4_cbrt',
#        'BILL_AMT4_cbrt_binned', 'BILL_AMT5_cbrt', 'BILL_AMT5_cbrt_binned',
#        'BILL_AMT6_cbrt', 'BILL_AMT6_cbrt_binned', 'PAY_AMT1_cbrt',
#        'PAY_AMT1_cbrt_binned', 'PAY_AMT2_cbrt', 'PAY_AMT2_cbrt_binned',
#        'PAY_AMT3_cbrt', 'PAY_AMT3_cbrt_binned', 'PAY_AMT4_cbrt',
#        'PAY_AMT4_cbrt_binned', 'PAY_AMT5_cbrt', 'PAY_AMT5_cbrt_binned',
#        'PAY_AMT6_cbrt', 'PAY_AMT6_cbrt_binned', 'AGE_sqrt'],
#       dtype='object', name=0)

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['BILL_AMT2'], bins=30, kde=True)
plt.title('Distribution of bill_amt_2')
plt.show()

# %%
df['BILL_AMT2'].skew()
# Out:
# 2.7052208534082856

# %%
df['BILL_AMT2'] = pd.to_numeric(df['BILL_AMT2'], errors='coerce')
df['BILL_AMT2_cbrt'] = np.cbrt(df['BILL_AMT2'])

# %%
df['BILL_AMT2_cbrt'].skew()
# Out:
# 0.1440832148888732

# %%
sns.boxplot(x=df['BILL_AMT2_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT2_cbrt'>

# %%
Q1 = df['BILL_AMT2_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT2_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT2_cbrt'] = df['BILL_AMT2_cbrt'].clip(lower=lower_bound, upper=upper_bound)

# %%
sns.boxplot(x=df['BILL_AMT2_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT2_cbrt'>

# %%
df['BILL_AMT2_cbrt'].value_counts()
# Out:
# BILL_AMT2_cbrt
# 0.000000     2506
# 7.306144      231
# 6.882389       75
# 9.205164       75
# 6.811285       72
#              ...
# 22.242496       1
# 52.171402       1
# 28.788795       1
# 27.219068       1
# 36.569393       1
# Name: count, Length: 22283, dtype: int64

# %%
df['BILL_AMT2_cbrt_binned'] = pd.qcut(df['BILL_AMT2_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['BILL_AMT2_cbrt_binned'] = df['BILL_AMT2_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
print(df[['BILL_AMT2_cbrt_binned', 'BILL_AMT2_cbrt']])

# %%
df['BILL_AMT1_cbrt'].value_counts()

# %% [markdown]
# ## For Bill amount 3

# %%
df['BILL_AMT3'].describe()
# Out:
# count     30000
# unique    22026
# top           0
# freq       2870
# Name: BILL_AMT3, dtype: int64

# %%
df['BILL_AMT3'].nunique()
# Out:
# 22026

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['BILL_AMT3'], bins=30, kde=True)
plt.title('Distribution of bill_amt_3')
plt.show()

# %%
df['BILL_AMT3'] = pd.to_numeric(df['BILL_AMT3'], errors='coerce')
df['BILL_AMT3_cbrt'] = np.cbrt(df['BILL_AMT3'])

# %%
sns.boxplot(x=df['BILL_AMT3_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT3_cbrt'>

# %%
Q1 = df['BILL_AMT3_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT3_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT3_cbrt'] = df['BILL_AMT3_cbrt'].clip(lower=lower_bound, upper=upper_bound)

# %%
sns.boxplot(x=df['BILL_AMT3_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT3_cbrt'>

# %%
df['BILL_AMT3_cbrt'].value_counts()
# Out:
# BILL_AMT3_cbrt
# 0.000000     2870
# 7.306144      275
# 9.205164       74
# 6.882389       63
# 77.161435      62
#              ...
# 35.656454       1
# 67.607529       1
# 54.539516       1
# 30.705148       1
# 36.782261       1
# Name: count, Length: 21954, dtype: int64

# %%
df['BILL_AMT3_cbrt'].nunique()
# Out:
# 21954

# %%
df['BILL_AMT3_cbrt_binned'] = pd.qcut(df['BILL_AMT3_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['BILL_AMT3_cbrt_binned'] = df['BILL_AMT3_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
print(df[['BILL_AMT3_cbrt_binned', 'BILL_AMT3_cbrt']])
# Out:
# 0     BILL_AMT3_cbrt_binned  BILL_AMT3_cbrt
# 0                         1        8.832285
# 1                         1       13.893754
# 2                         2       23.845653
# 3                         3       36.665353
# 4                         2       32.968749
# ...                     ...             ...
# 29995                     3       59.284559
# 29996                     1       15.185836
# 29997                     1       14.023769
# 29998                     3       42.414638
# 29999                     3       36.782261
#
# [30000 rows x 2 columns]

# %% [markdown]
# ## For Bill amount 4

# %%
df['BILL_AMT4'].describe()
# Out:
# count     30000
# unique    21548
# top           0
# freq       3195
# Name: BILL_AMT4, dtype: int64

# %%
df['BILL_AMT4'].nunique()
# Out:
# 21548

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['BILL_AMT4'], bins=30, kde=True)
plt.title('Distribution of bill_amt_4')
plt.show()

# %%
df['BILL_AMT4'] = pd.to_numeric(df['BILL_AMT4'], errors='coerce')
df['BILL_AMT4_cbrt'] = np.cbrt(df['BILL_AMT4'])

# %%
df['BILL_AMT4_cbrt'].skew()
# Out:
# 0.14328321043109443

# %%
sns.boxplot(x=df['BILL_AMT4_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT4_cbrt'>

# %%
Q1 = df['BILL_AMT4_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT4_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT4_cbrt'] = df['BILL_AMT4_cbrt'].clip(lower=lower_bound, upper=upper_bound)

# %%
sns.boxplot(x=df['BILL_AMT4_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT4_cbrt'>

# %%
df['BILL_AMT4_cbrt'].nunique()
# Out:
# 21548

# %%
df['BILL_AMT4_cbrt_binned'] = pd.qcut(df['BILL_AMT4_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['BILL_AMT4_cbrt_binned'] = df['BILL_AMT4_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
print(df[['BILL_AMT4_cbrt_binned', 'BILL_AMT4_cbrt']])
# Out:
# 0     BILL_AMT4_cbrt_binned  BILL_AMT4_cbrt
# 0                         1        0.000000
# 1                         1       14.845828
# 2                         2       24.289887
# 3                         2       30.478979
# 4                         2       27.562941
# ...                     ...             ...
# 29995                     3       44.480276
# 29996                     2       20.784647
# 29997                     2       27.535711
# 29998                     3       37.509390
# 29999                     2       33.182037
#
# [30000 rows x 2 columns]

# %% [markdown]
# # For Bill amount 5

# %%
df['BILL_AMT5'].describe()
# Out:
# count     30000
# unique    21010
# top           0
# freq       3506
# Name: BILL_AMT5, dtype: int64

# %%
df['BILL_AMT5'].nunique()
# Out:
# 21010

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['BILL_AMT5'], bins=30, kde=True)
plt.title('Distribution of bill_amt_5')
plt.show()

# %%
df['BILL_AMT5'] = pd.to_numeric(df['BILL_AMT5'], errors='coerce')
df['BILL_AMT5_cbrt'] = np.cbrt(df['BILL_AMT5'])

# %%
df['BILL_AMT5_cbrt'].skew()
# Out:
# 0.1598484820025543

# %%
sns.boxplot(x=df['BILL_AMT5_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT5_cbrt'>

# %%
Q1 = df['BILL_AMT5_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT5_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT5_cbrt'] = df['BILL_AMT5_cbrt'].clip(lower=lower_bound, upper=upper_bound)

# %%
sns.boxplot(x=df['BILL_AMT5_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT5_cbrt'>

# %%
df['BILL_AMT5_cbrt_binned'] = pd.qcut(df['BILL_AMT5_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['BILL_AMT5_cbrt_binned'] = df['BILL_AMT5_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
print(df[['BILL_AMT5_cbrt_binned', 'BILL_AMT5_cbrt']])
# Out:
# 0     BILL_AMT5_cbrt_binned  BILL_AMT5_cbrt
# 0                         1        0.000000
# 1                         1       15.117594
# 2                         2       24.633589
# 3                         2       30.708683
# 4                         2       26.752191
# ...                     ...             ...
# 29995                     2       31.493658
# 29996                     1       17.313669
# 29997                     2       27.404961
# 29998                     2       22.801698
# 29999                     2       31.888938
#
# [30000 rows x 2 columns]

# %% [markdown]
# ## For Bill amount 6

# %%
df['BILL_AMT6'].describe()
# Out:
# count     30000.000000
# mean      38871.760400
# std       59554.107537
# min     -339603.000000
# 25%        1256.000000
# 50%       17071.000000
# 75%       49198.250000
# max      961664.000000
# Name: BILL_AMT6, dtype: float64

# %%
df['BILL_AMT6'].nunique()
# Out:
# 20604

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['BILL_AMT6'], bins=30, kde=True)
plt.title('Distribution of bill_amt_6')
plt.show()

# %%
df['BILL_AMT6'] = pd.to_numeric(df['BILL_AMT6'], errors='coerce')
df['BILL_AMT6_cbrt'] = np.cbrt(df['BILL_AMT6'])

# %%
df['BILL_AMT6_cbrt'].skew()
# Out:
# 0.15650735628780196

# %%
sns.boxplot(x=df['BILL_AMT6_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT6_cbrt'>

# %%
Q1 = df['BILL_AMT6_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT6_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT6_cbrt'] = df['BILL_AMT6_cbrt'].clip(lower=lower_bound, upper=upper_bound)

# %%
sns.boxplot(x=df['BILL_AMT6_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT6_cbrt'>

# %%
df['BILL_AMT6_cbrt_binned'] = pd.qcut(df['BILL_AMT6_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['BILL_AMT6_cbrt_binned'] = df['BILL_AMT6_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
print(df[['BILL_AMT6_cbrt_binned', 'BILL_AMT6_cbrt']])
# Out:
# 0     BILL_AMT6_cbrt_binned  BILL_AMT6_cbrt
# 0                         1        0.000000
# 1                         1       14.829173
# 2                         2       24.959401
# 3                         2       30.915134
# 4                         2       26.745203
# ...                     ...             ...
# 29995                     2       25.187917
# 29996                     1        0.000000
# 29997                     2       26.850107
# 29998                     3       36.579112
# 29999                     2       24.832480
#
# [30000 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'LIMIT_BAL_sqrt', 'BILL_AMT2_cbrt'],
#       dtype='object', name=0)

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'LIMIT_BAL_sqrt', 'BILL_AMT1_cbrt',
#        'BILL_AMT1_cbrt_binned', 'BILL_AMT2_cbrt', 'BILL_AMT2_cbrt_binned',
#        'BILL_AMT3_cbrt', 'BILL_AMT3_cbrt_binned', 'BILL_AMT4_cbrt',
#        'BILL_AMT4_cbrt_binned', 'BILL_AMT5_cbrt', 'BILL_AMT5_cbrt_binned',
#        'BILL_AMT6_cbrt', 'BILL_AMT6_cbrt_binned', 'PAY_AMT1_cbrt',
#        'PAY_AMT1_cbrt_binned', 'PAY_AMT2_cbrt', 'PAY_AMT2_cbrt_binned',
#        'PAY_AMT3_cbrt', 'PAY_AMT3_cbrt_binned', 'PAY_AMT4_cbrt',
#        'PAY_AMT4_cbrt_binned', 'PAY_AMT5_cbrt', 'PAY_AMT5_cbrt_binned',
#        'PAY_AMT6_cbrt', 'PAY_AMT6_cbrt_binned'],
#       dtype='object', name=0)

# %% [markdown]
# ## PAY_AMT1

# %%
df['PAY_AMT1'].nunique()
# Out:
# 7943

# %%
df['PAY_AMT1'].dtype
# Out:
# dtype('O')

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['PAY_AMT1'],bins=30,kde=30)
plt.title('Distribution of pay_amt1')
plt.show()

# %%
df['PAY_AMT1'].skew()
# Out:
# 14.66836433284317

# %%
df['PAY_AMT1']=pd.to_numeric(df['PAY_AMT1'],errors='coerce')
df['PAY_AMT1_cbrt'] = np.cbrt(df['PAY_AMT1'])

# %%
df['PAY_AMT1_cbrt'].skew()
# Out:
# 0.8355355554768573

# %%
sns.boxplot(x=df['PAY_AMT1_cbrt'])
# Out:
# <Axes: xlabel='PAY_AMT1_cbrt'>

# %%
Q1 = df['PAY_AMT1_cbrt'].quantile(0.25)
Q3 = df['PAY_AMT1_cbrt'].quantile(0.75)

# %%
print(Q1,Q3)
# Out:
# 10.0 17.10659663641468

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 7.106596636414679

# %%
upper_bound=Q3+1.5*IQR
print(upper_bound)
# Out:
# 27.766491591036697

# %%
lower_bound=Q1-1.5*IQR
print(lower_bound)
# Out:
# -0.6598949546220183

# %%
df.loc[df['PAY_AMT1_cbrt'] > upper_bound, 'PAY_AMT1_cbrt']
# Out:
# 6        38.029525
# 11       27.942911
# 48       27.823722
# 88       34.199519
# 151      31.072325
#            ...
# 29948    33.921387
# 29963    68.613112
# 29970    37.551278
# 29988    40.207258
# 29998    44.122934
# Name: PAY_AMT1_cbrt, Length: 1179, dtype: float64

# %%
len(df[df['PAY_AMT1_cbrt']>upper_bound])
# Out:
# 1179

# %%
df.loc[df['PAY_AMT1_cbrt']<lower_bound, 'PAY_AMT1_cbrt']
# Out:
# Series([], Name: PAY_AMT1_cbrt, dtype: float64)

# %%
len(df[df['PAY_AMT1_cbrt']<lower_bound])
# Out:
# 0

# %%
df['PAY_AMT1_cbrt'].shape[0]
# Out:
# 30000

# %%
(len(df[df['PAY_AMT1_cbrt'] > upper_bound]) / df['PAY_AMT1_cbrt'].shape[0])*100
# Out:
# 3.93

# %%
Q1 = df['PAY_AMT1_cbrt'].quantile(0.25)
Q3 = df['PAY_AMT1_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['PAY_AMT1_cbrt'] = df['PAY_AMT1_cbrt'].clip(lower=lower_bound, upper=upper_bound)

# %%
sns.boxplot(x=df['PAY_AMT1_cbrt'])
# Out:
# <Axes: xlabel='PAY_AMT1_cbrt'>

# %%
df['PAY_AMT1_cbrt'].nunique()
# Out:
# 6940

# %%
df['PAY_AMT1_cbrt_binned'] = pd.qcut(df['PAY_AMT1_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['PAY_AMT1_cbrt_binned'] = df['PAY_AMT1_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
print(df[['PAY_AMT1_cbrt_binned', 'PAY_AMT1_cbrt']])
# Out:
# 0     PAY_AMT1_cbrt_binned  PAY_AMT1_cbrt
# 0                        1       0.000000
# 1                        1       0.000000
# 2                        2      11.492749
# 3                        2      12.599210
# 4                        2      12.599210
# ...                    ...            ...
# 29995                    3      20.408276
# 29996                    2      12.247188
# 29997                    1       0.000000
# 29998                    3      27.766492
# 29999                    2      12.760916
#
# [30000 rows x 2 columns]

# %% [markdown]
# ## PAY_AMT2

# %%
df['PAY_AMT2'].describe()
# Out:
# count     30000
# unique     7899
# top           0
# freq       5396
# Name: PAY_AMT2, dtype: int64

# %%
df['PAY_AMT2'].nunique()
# Out:
# 7899

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['PAY_AMT2'] , bins=30, kde=True)
plt.title('distribution of pay_atm2')
plt.show()

# %%
df['PAY_AMT2'].skew()
# Out:
# 30.45381745016943

# %%
sns.boxplot(x=df['PAY_AMT2'])
# Out:
# <Axes: xlabel='PAY_AMT2'>

# %%
df['PAY_AMT2'].dtype
# Out:
# dtype('O')

# %%
df['PAY_AMT2']=pd.to_numeric(df['PAY_AMT2'],errors='coerce')

# %%
df['PAY_AMT2'].dtype
# Out:
# dtype('int64')

# %%
df['PAY_AMT2_cbrt']=np.cbrt(df['PAY_AMT2'])

# %%
df['PAY_AMT2_cbrt'].skew()
# Out:
# 1.1091125603767158

# %%
Q1 = df['PAY_AMT1_cbrt'].quantile(0.25)
Q3 = df['PAY_AMT1_cbrt'].quantile(0.75)

# %%
print(Q1,Q3)
# Out:
# 10.0 17.10659663641468

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 7.106596636414679

# %%
upper_bound=Q3+1.5*IQR
print(upper_bound)
# Out:
# 27.766491591036697

# %%
lower_bound=Q1-1.5*IQR
print(lower_bound)
# Out:
# -0.6598949546220183

# %%
df.loc[df['PAY_AMT2_cbrt'] > upper_bound, 'PAY_AMT2_cbrt']
# Out:
# 4        33.226178
# 6        34.199519
# 33       28.367188
# 34       31.473817
# 74       28.624163
#            ...
# 29913    31.082334
# 29957    66.517963
# 29959    47.646712
# 29970    40.111149
# 29993    48.171838
# Name: PAY_AMT2_cbrt, Length: 1201, dtype: float64

# %%
len(df[df['PAY_AMT2_cbrt']>upper_bound])
# Out:
# 1201

# %%
df.loc[df['PAY_AMT2_cbrt']<lower_bound, 'PAY_AMT2_cbrt']
# Out:
# Series([], Name: PAY_AMT2_cbrt, dtype: float64)

# %%
len(df[df['PAY_AMT2_cbrt']<lower_bound])
# Out:
# 0

# %%
(len(df[df['PAY_AMT2_cbrt'] > upper_bound]) / df['PAY_AMT2_cbrt'].shape[0])*100
# Out:
# 4.003333333333333

# %%
Q1 = df['PAY_AMT2_cbrt'].quantile(0.25)
Q3 = df['PAY_AMT2_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['PAY_AMT2_cbrt'] = df['PAY_AMT2_cbrt'].clip(lower=lower_bound, upper=upper_bound)

# %%
sns.boxplot(x=df['PAY_AMT2_cbrt'])
# Out:
# <Axes: xlabel='PAY_AMT2_cbrt'>

# %%
df['PAY_AMT2_cbrt'].nunique()
# Out:
# 6949

# %%
df['PAY_AMT2_cbrt_binned'] = pd.qcut(df['PAY_AMT2_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['PAY_AMT2_cbrt_binned'] = df['PAY_AMT2_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
print(df[['PAY_AMT2_cbrt_binned', 'PAY_AMT2_cbrt']])
# Out:
# 0     PAY_AMT2_cbrt_binned  PAY_AMT2_cbrt
# 0                        1       8.832285
# 1                        1      10.000000
# 2                        2      11.447142
# 3                        2      12.638982
# 4                        3      28.635741
# ...                    ...            ...
# 29995                    3      27.144176
# 29996                    2      15.220448
# 29997                    1       0.000000
# 29998                    2      15.050202
# 29999                    2      12.164404
#
# [30000 rows x 2 columns]

# %% [markdown]
# ## PAY_AMT3

# %%
df['PAY_AMT3'].describe()
# Out:
# count     30000
# unique     7518
# top           0
# freq       5968
# Name: PAY_AMT3, dtype: int64

# %%
df['PAY_AMT3'].nunique()
# Out:
# 7518

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['PAY_AMT3'] , bins=30, kde=True)
plt.title('distribution of pay_atm3')
plt.show()

# %%
df['PAY_AMT3'].skew()
# Out:
# 17.216635435129238

# %%
sns.boxplot(x=df['PAY_AMT3'])
# Out:
# <Axes: xlabel='PAY_AMT3'>

# %%
df['PAY_AMT3'].dtype
# Out:
# dtype('O')

# %%
df['PAY_AMT3']=pd.to_numeric(df['PAY_AMT3'],errors='coerce')

# %%
df['PAY_AMT3'].dtype
# Out:
# dtype('int64')

# %%
df['PAY_AMT3_cbrt']=np.cbrt(df['PAY_AMT3'])

# %%
df['PAY_AMT3_cbrt'].skew()
# Out:
# 1.0503099548631

# %%
Q1 = df['BILL_AMT3_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT3_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT3_cbrt'] = df['BILL_AMT3_cbrt'].clip(lower=lower_bound, upper=upper_bound)

# %%
sns.boxplot(x=df['BILL_AMT3_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT3_cbrt'>

# %%
df['PAY_AMT3_cbrt'].nunique()
# Out:
# 7518

# %%
df['PAY_AMT3_cbrt_binned'] = pd.qcut(df['PAY_AMT3_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['PAY_AMT3_cbrt_binned'] = df['PAY_AMT3_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
print(df[['PAY_AMT3_cbrt_binned', 'PAY_AMT3_cbrt']])
# Out:
# 0     PAY_AMT3_cbrt_binned  PAY_AMT3_cbrt
# 0                        1       0.000000
# 1                        1      10.000000
# 2                        1      10.000000
# 3                        2      10.626586
# 4                        3      21.544347
# ...                    ...            ...
# 29995                    3      17.103179
# 29996                    3      20.799297
# 29997                    3      28.020393
# 29998                    2      10.561244
# 29999                    2      11.266232
#
# [30000 rows x 2 columns]

# %% [markdown]
# ## PAY_AMT4

# %%
df['PAY_AMT4'].describe()
# Out:
# count     30000
# unique     6937
# top           0
# freq       6408
# Name: PAY_AMT4, dtype: int64

# %%
df['PAY_AMT4'].nunique()
# Out:
# 6937

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['PAY_AMT4'] , bins=30, kde=True)
plt.title('distribution of pay_atm4')
plt.show()

# %%
df['PAY_AMT4'].skew()
# Out:
# 12.904984823542545

# %%
sns.boxplot(x=df['PAY_AMT4'])
# Out:
# <Axes: xlabel='PAY_AMT4'>

# %%
df['PAY_AMT4'].dtype
# Out:
# dtype('O')

# %%
df['PAY_AMT4']=pd.to_numeric(df['PAY_AMT4'],errors='coerce')

# %%
df['PAY_AMT4'].dtype
# Out:
# dtype('int64')

# %%
df['PAY_AMT4_cbrt']=np.cbrt(df['PAY_AMT4'])

# %%
df['PAY_AMT4_cbrt'].skew()
# Out:
# 1.0623217905306697

# %%
Q1 = df['BILL_AMT4_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT4_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT4_cbrt'] = df['BILL_AMT4_cbrt'].clip(lower=lower_bound, upper=upper_bound)

# %%
sns.boxplot(x=df['BILL_AMT4_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT4_cbrt'>

# %%
df['PAY_AMT4_cbrt'].nunique()
# Out:
# 6937

# %%
df['PAY_AMT4_cbrt_binned'] = pd.qcut(df['PAY_AMT4_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['PAY_AMT4_cbrt_binned'] = df['PAY_AMT4_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
print(df[['PAY_AMT4_cbrt_binned', 'PAY_AMT4_cbrt']])
# Out:
# 0     PAY_AMT4_cbrt_binned  PAY_AMT4_cbrt
# 0                        1       0.000000
# 1                        2      10.000000
# 2                        2      10.000000
# 3                        2      10.322801
# 4                        3      20.800838
# ...                    ...            ...
# 29995                    3      14.497423
# 29996                    1       5.052774
# 29997                    3      16.134286
# 29998                    2      12.441863
# 29999                    2      10.000000
#
# [30000 rows x 2 columns]

# %% [markdown]
# ## PAY_AMT5

# %%
df['PAY_AMT5'].describe()
# Out:
# count     30000
# unique     6897
# top           0
# freq       6703
# Name: PAY_AMT5, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['PAY_AMT5'] , bins=30, kde=True)
plt.title('distribution of pay_atm5')
plt.show()

# %%
df['PAY_AMT5'].skew()
# Out:
# 11.127417052173817

# %%
sns.boxplot(x=df['PAY_AMT5'])
# Out:
# <Axes: xlabel='PAY_AMT5'>

# %%
df['PAY_AMT5'].dtype
# Out:
# dtype('O')

# %%
df['PAY_AMT5']=pd.to_numeric(df['PAY_AMT5'],errors='coerce')

# %%
df['PAY_AMT5_cbrt']=np.cbrt(df['PAY_AMT5'])

# %%
df['PAY_AMT5_cbrt'].skew()
# Out:
# 1.0308740494007091

# %%
Q1 = df['BILL_AMT5_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT5_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT5_cbrt'] = df['BILL_AMT5_cbrt'].clip(lower=lower_bound, upper=upper_bound)

# %%
sns.boxplot(x=df['BILL_AMT5_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT5_cbrt'>

# %%
df['PAY_AMT5_cbrt'].nunique()
# Out:
# 6897

# %%
df['PAY_AMT5_cbrt_binned'] = pd.qcut(df['PAY_AMT5_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['PAY_AMT5_cbrt_binned'] = df['PAY_AMT5_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
print(df[['PAY_AMT5_cbrt_binned', 'PAY_AMT5_cbrt']])
# Out:
# 0     PAY_AMT5_cbrt_binned  PAY_AMT5_cbrt
# 0                        1       0.000000
# 1                        1       0.000000
# 2                        2      10.000000
# 3                        2      10.224904
# 4                        1       8.832285
# ...                    ...            ...
# 29995                    3      17.099759
# 29996                    1       0.000000
# 29997                    2      12.599210
# 29998                    3      37.554351
# 29999                    2      10.000000
#
# [30000 rows x 2 columns]

# %% [markdown]
# # PAY_AMT6

# %%
df['PAY_AMT6'].describe()
# Out:
# count     30000
# unique     6939
# top           0
# freq       7173
# Name: PAY_AMT6, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['PAY_AMT6'] , bins=30, kde=True)
plt.title('distribution of pay_atm6')
plt.show()

# %%
df['PAY_AMT6'].skew()
# Out:
# 10.640727325044317

# %%
sns.boxplot(x=df['PAY_AMT6'])
# Out:
# <Axes: xlabel='PAY_AMT6'>

# %%
df['PAY_AMT6'].dtype
# Out:
# dtype('O')

# %%
df['PAY_AMT6']=pd.to_numeric(df['PAY_AMT6'],errors='coerce')

# %%
df['PAY_AMT6_cbrt']=np.cbrt(df['PAY_AMT6'])

# %%
df['PAY_AMT6_cbrt'].skew()
# Out:
# 1.204077814547615

# %%
Q1 = df['BILL_AMT6_cbrt'].quantile(0.25)
Q3 = df['BILL_AMT6_cbrt'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['BILL_AMT6_cbrt'] = df['BILL_AMT6_cbrt'].clip(lower=lower_bound, upper=upper_bound)

# %%
sns.boxplot(x=df['BILL_AMT6_cbrt'])
# Out:
# <Axes: xlabel='BILL_AMT6_cbrt'>

# %%
df['PAY_AMT6_cbrt'].nunique()
# Out:
# 6939

# %%
df['PAY_AMT6_cbrt_binned'] = pd.qcut(df['PAY_AMT6_cbrt'], q=3, labels=['Low', 'Medium', 'High'])
df['PAY_AMT6_cbrt_binned'] = df['PAY_AMT6_cbrt_binned'].replace({'Low': 1, 'Medium': 2, 'High': 3})
print(df[['PAY_AMT6_cbrt_binned', 'PAY_AMT6_cbrt']])
# Out:
# 0     PAY_AMT6_cbrt_binned  PAY_AMT6_cbrt
# 0                        1       0.000000
# 1                        2      12.599210
# 2                        3      17.099759
# 3                        2      10.000000
# 4                        2       8.789347
# ...                    ...            ...
# 29995                    2      10.000000
# 29996                    1       0.000000
# 29997                    3      14.580997
# 29998                    2      12.173408
# 29999                    2      10.000000
#
# [30000 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'LIMIT_BAL_sqrt', 'BILL_AMT1_cbrt',
#        'BILL_AMT1_cbrt_binned', 'BILL_AMT2_cbrt', 'BILL_AMT2_cbrt_binned',
#        'BILL_AMT3_cbrt', 'BILL_AMT3_cbrt_binned', 'BILL_AMT4_cbrt',
#        'BILL_AMT4_cbrt_binned', 'BILL_AMT5_cbrt', 'BILL_AMT5_cbrt_binned',
#        'BILL_AMT6_cbrt', 'BILL_AMT6_cbrt_binned', 'PAY_AMT1_cbrt',
#        'PAY_AMT1_cbrt_binned', 'PAY_AMT2_cbrt', 'PAY_AMT2_cbrt_binned',
#        'PAY_AMT3_cbrt', 'PAY_AMT3_cbrt_binned', 'PAY_AMT4_cbrt',
#        'PAY_AMT4_cbrt_binned', 'PAY_AMT5_cbrt', 'PAY_AMT5_cbrt_binned',
#        'PAY_AMT6_cbrt', 'PAY_AMT6_cbrt_binned'],
#       dtype='object', name=0)

# %% [markdown]
# # EDA

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 3: Set up the plot style
sns.set(style="darkgrid")

# Step 4: Plot Count Plot for 'SEX'
plt.figure(figsize=(6,4))
sns.countplot(x='SEX', data=df)
plt.title('Count of Customers by Sex')
plt.show()

# Step 5: Plot Count Plot for 'EDUCATION'
plt.figure(figsize=(6,4))
sns.countplot(x='EDUCATION', data=df)
plt.title('Count of Customers by Education')
plt.show()

# Step 6: Plot Count Plot for 'MARRIAGE'
plt.figure(figsize=(6,4))
sns.countplot(x='MARRIAGE', data=df)
plt.title('Count of Customers by Marital Status')
plt.show()

# %%
# for transformed limit balance sqrt column

# Step 2: Set up the plot style
sns.set(style="whitegrid")

# Step 3: Box Plot for LIMIT_BAL vs SEX
plt.figure(figsize=(6,4))
sns.boxplot(x='SEX', y='LIMIT_BAL_sqrt', data=df)
plt.title('LIMIT_BAL_sqrt Distribution by SEX')
plt.show()

# Step 4: Box Plot for LIMIT_BAL vs EDUCATION
plt.figure(figsize=(6,4))
sns.boxplot(x='EDUCATION', y='LIMIT_BAL_sqrt', data=df)
plt.title('LIMIT_BAL_sqrt Distribution by EDUCATION')
plt.show()

# Step 5: Box Plot for LIMIT_BAL vs MARRIAGE
plt.figure(figsize=(6,4))
sns.boxplot(x='MARRIAGE', y='LIMIT_BAL_sqrt', data=df)
plt.title('LIMIT_BAL_sqrt Distribution by MARRIAGE')
plt.show()

# %%
# for non transformed limit balance

# Step 2: Set up the plot style
sns.set(style="whitegrid")

# Step 3: Box Plot for LIMIT_BAL vs SEX
plt.figure(figsize=(6,4))
sns.boxplot(x='SEX', y='LIMIT_BAL', data=df)
plt.title('LIMIT_BAL Distribution by SEX')
plt.show()

# Step 4: Box Plot for LIMIT_BAL vs EDUCATION
plt.figure(figsize=(6,4))
sns.boxplot(x='EDUCATION', y='LIMIT_BAL', data=df)
plt.title('LIMIT_BAL Distribution by EDUCATION')
plt.show()

# Step 5: Box Plot for LIMIT_BAL vs MARRIAGE
plt.figure(figsize=(6,4))
sns.boxplot(x='MARRIAGE', y='LIMIT_BAL', data=df)
plt.title('LIMIT_BAL Distribution by MARRIAGE')
plt.show()

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'LIMIT_BAL_sqrt', 'BILL_AMT1_cbrt',
#        'BILL_AMT1_cbrt_binned', 'BILL_AMT2_cbrt', 'BILL_AMT2_cbrt_binned',
#        'BILL_AMT3_cbrt', 'BILL_AMT3_cbrt_binned', 'BILL_AMT4_cbrt',
#        'BILL_AMT4_cbrt_binned', 'BILL_AMT5_cbrt', 'BILL_AMT5_cbrt_binned',
#        'BILL_AMT6_cbrt', 'BILL_AMT6_cbrt_binned', 'PAY_AMT1_cbrt',
#        'PAY_AMT1_cbrt_binned', 'PAY_AMT2_cbrt', 'PAY_AMT2_cbrt_binned',
#        'PAY_AMT3_cbrt', 'PAY_AMT3_cbrt_binned', 'PAY_AMT4_cbrt',
#        'PAY_AMT4_cbrt_binned', 'PAY_AMT5_cbrt', 'PAY_AMT5_cbrt_binned',
#        'PAY_AMT6_cbrt', 'PAY_AMT6_cbrt_binned'],
#       dtype='object', name=0)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Select only the bill and payment amount columns
bill_columns = ['BILL_AMT1_cbrt', 'BILL_AMT2_cbrt', 'BILL_AMT3_cbrt', 'BILL_AMT4_cbrt', 'BILL_AMT5_cbrt', 'BILL_AMT6_cbrt']
payment_columns = ['PAY_AMT1_cbrt', 'PAY_AMT2_cbrt', 'PAY_AMT3_cbrt', 'PAY_AMT4_cbrt', 'PAY_AMT5_cbrt', 'PAY_AMT6_cbrt']

# Step 2: Create a new DataFrame for bill and payment amounts
bill_payment_df = df[bill_columns + payment_columns]

# Step 3: Calculate the correlation matrix
correlation_matrix = bill_payment_df.corr()

# Step 4: Plot the correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between BILL_AMT_cbrt and PAY_AMT_cbrt Columns')
plt.show()

# %%
# Step 1: Select only the bill and payment amount columns
bill_columns = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
payment_columns = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# Step 2: Create a new DataFrame for bill and payment amounts
bill_payment_df = df[bill_columns + payment_columns]

# Step 3: Calculate the correlation matrix
correlation_matrix = bill_payment_df.corr()

# Step 4: Plot the correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation between BILL_AMT and PAY_AMT Columns')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Define the payment status columns
pay_columns = ['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

# Step 2: Initialize a list to store default rates for each payment status
default_rates = []

# Step 3: Calculate the default rate for each payment status column
for col in pay_columns:
    # Group by payment status and calculate the mean of default payments
    default_rate_by_status = df.groupby(col)['default payment next month'].mean()
    # Store the result as a DataFrame for easy plotting
    default_rates.append(default_rate_by_status)

# Step 4: Plot the default rates for each payment status column
plt.figure(figsize=(12, 6))

for i, col in enumerate(pay_columns):
    plt.plot(default_rates[i].index, default_rates[i].values, marker='o', label=col)

# Step 5: Customize the plot
plt.title('Default Rate by Payment Status (PAY_0 to PAY_6)')
plt.xlabel('Payment Status (Months Behind)')
plt.ylabel('Default Rate')
plt.legend(title='PAY_ Columns')
plt.grid(True)
plt.show()
